# %%
# library import
import pandas as pd
import folium
import matplotlib.pyplot as plt

# %%
# import the csv file
df = pd.read_csv('mydata.csv')

# %%
df
# Out:
#                           name  \
# 0                    広島平和記念資料館
# 1                     広島 原爆ドーム
# 2                     広島平和記念公園
# 3                   広島原子爆弾 爆心地
# 4                      長崎原爆資料館
# 5              長崎原爆死没者 追悼平和祈念館
# 6                 長崎原子爆弾落下中心地碑
# 7                        爆心地公園
# 8                         平和の泉
# 9             山王神社二の鳥居（長崎原爆遺跡）
# 10            カトリック浦上教会（浦上天主堂）
# 11                        平和公園
# 12                       平和祈念像
# 13                      ひめゆりの塔
# 14                 ひめゆり平和祈念資料館
# 15                      ひむかいの塔
# 16                        梯梧之塔
# 17                        琉風之碑
# 18                  水俣市立水俣病資料館
# 19       阪神・淡路大震災記念 人と防災未来センター
# 20              東京大空襲・戦災資料センター
# 21                   平和祈念展示資料館
# 22  アクティブ・ミュージアム「女たちの戦争と平和資料館」
# 23             しょうけい館（戦傷病者史料館）
# 24                         遊就館
# 25              戦没画学生慰霊美術館 無言館
# 26         傷ついた画布のドーム オリーヴの読書館
#
#                                           description   latitude   longitude  \
# 0                                                 NaN  34.408173  132.467386
# 1                                                 NaN  34.396138  132.453678
# 2   所在】広島県広島市中区大手町1丁目10\r\n【利用料金】無料\r\n【駐車場】周辺の有料駐...  34.393312  132.452349
# 3   広島の原爆の爆心地は、相生橋の南東、島病院であった。 当初の投下目標は相生橋であったが、風の...  34.395446  132.455053
# 4                                                 NaN  32.772628  129.865234
# 5                                                 NaN  32.772303  129.864987
# 6                                                 NaN  32.773909  129.863292
# 7                                                 NaN  32.773385  129.863142
# 8                                                 NaN  32.775658  129.863068
# 9                                                 NaN  32.768043  129.867220
# 10                                                NaN  32.777010  129.868504
# 11                                                NaN  32.777102  129.863051
# 12                                                NaN  32.777636  129.864278
# 13  【所在】沖縄県糸満市字伊原671-1\r\n【営業時間】9時～17時25分（入館は17時まで...  26.096616  127.690669
# 14                                                NaN  26.096491  127.690262
# 15                                                NaN  26.095036  127.693319
# 16                                                NaN  26.097098  127.691806
# 17                                                NaN  26.096700  127.685584
# 18  【所在】熊本県水俣市明神町53番地\n【営業時間】9時～17時\n【定休日】月曜日（月曜が祝...  32.203713  130.374699
# 19  【所在】兵庫県神戸市中央区脇浜海岸通1-5-2\n【営業時間】9時～17時30分（入館は16...  34.698483  135.210000
# 20                                                NaN  35.686044  139.822356
# 21                                                NaN  35.696300  139.687789
# 22                                                NaN  35.713864  139.715941
# 23                                                NaN  35.704664  139.754393
# 24                                                NaN  35.702104  139.743616
# 25                                                NaN  36.345665  138.200038
# 26                                                NaN  36.344233  138.200674
#
#          color
# 0       orange
# 1          red
# 2       orange
# 3       orange
# 4         blue
# 5         blue
# 6         blue
# 7         blue
# 8         blue
# 9         blue
# 10        blue
# 11        blue
# 12        blue
# 13         red
# 14   lightblue
# 15   lightblue
# 16   lightblue
# 17   lightblue
# 18         red
# 19         red
# 20       green
# 21       green
# 22       green
# 23       green
# 24       green
# 25  lightgreen
# 26  lightgreen

# %%
# size of the data (rows, columns)
df.shape
# Out:
# (27, 5)

# %%
# information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         27 non-null     object
#  1   description  5 non-null      object
#  2   latitude     27 non-null     float64
#  3   longitude    27 non-null     float64
#  4   color        27 non-null     object
# dtypes: float64(2), object(3)
# memory usage: 1.2+ KB

# %%
# list of columns
df.columns.to_list()
# Out:
# ['name', 'description', 'latitude', 'longitude', 'color']

# %%
# show only specific columns
df[['name','latitude','longitude']]
# Out:
#                           name   latitude   longitude
# 0                    広島平和記念資料館  34.408173  132.467386
# 1                     広島 原爆ドーム  34.396138  132.453678
# 2                     広島平和記念公園  34.393312  132.452349
# 3                   広島原子爆弾 爆心地  34.395446  132.455053
# 4                      長崎原爆資料館  32.772628  129.865234
# 5              長崎原爆死没者 追悼平和祈念館  32.772303  129.864987
# 6                 長崎原子爆弾落下中心地碑  32.773909  129.863292
# 7                        爆心地公園  32.773385  129.863142
# 8                         平和の泉  32.775658  129.863068
# 9             山王神社二の鳥居（長崎原爆遺跡）  32.768043  129.867220
# 10            カトリック浦上教会（浦上天主堂）  32.777010  129.868504
# 11                        平和公園  32.777102  129.863051
# 12                       平和祈念像  32.777636  129.864278
# 13                      ひめゆりの塔  26.096616  127.690669
# 14                 ひめゆり平和祈念資料館  26.096491  127.690262
# 15                      ひむかいの塔  26.095036  127.693319
# 16                        梯梧之塔  26.097098  127.691806
# 17                        琉風之碑  26.096700  127.685584
# 18                  水俣市立水俣病資料館  32.203713  130.374699
# 19       阪神・淡路大震災記念 人と防災未来センター  34.698483  135.210000
# 20              東京大空襲・戦災資料センター  35.686044  139.822356
# 21                   平和祈念展示資料館  35.696300  139.687789
# 22  アクティブ・ミュージアム「女たちの戦争と平和資料館」  35.713864  139.715941
# 23             しょうけい館（戦傷病者史料館）  35.704664  139.754393
# 24                         遊就館  35.702104  139.743616
# 25              戦没画学生慰霊美術館 無言館  36.345665  138.200038
# 26         傷ついた画布のドーム オリーヴの読書館  36.344233  138.200674

# %%
# get values for a single column
df['longitude']
# Out:
# 0     132.467386
# 1     132.453678
# 2     132.452349
# 3     132.455053
# 4     129.865234
# 5     129.864987
# 6     129.863292
# 7     129.863142
# 8     129.863068
# 9     129.867220
# 10    129.868504
# 11    129.863051
# 12    129.864278
# 13    127.690669
# 14    127.690262
# 15    127.693319
# 16    127.691806
# 17    127.685584
# 18    130.374699
# 19    135.210000
# 20    139.822356
# 21    139.687789
# 22    139.715941
# 23    139.754393
# 24    139.743616
# 25    138.200038
# 26    138.200674
# Name: longitude, dtype: float64

# %%
# put those values in a list
df['latitude'].to_list()
# Out:
# [34.40817299,
#  34.39613812,
#  34.39331227,
#  34.39544552,
#  32.77262813,
#  32.77230337,
#  32.7739087,
#  32.77338548,
#  32.77565821,
#  32.76804315,
#  32.7770102,
#  32.77710225,
#  32.77763606,
#  26.09661602,
#  26.09649076,
#  26.09503586,
#  26.09709777,
#  26.09670041,
#  32.20371293,
#  34.69848324,
#  35.68604378,
#  35.69630009,
#  35.7138638,
#  35.70466425,
#  35.7021045,
#  36.34566495,
#  36.34423261]

# %%
# line chart
df['latitude'].plot()
# Out:
# <Axes: >

# %%
# boxplot 箱ヒゲ図
df['latitude'].plot.box(color='red')
# Out:
# <Axes: >

# %%
# bar graph
df['latitude'].plot.bar(color='green')
# Out:
# <Axes: >

# %%
df.plot.scatter(x='longitude',y='latitude',c='color',s=60)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
# summary stats
df['latitude'].describe()
# Out:
# count    27.000000
# mean     32.634732
# std       3.426926
# min      26.095036
# 25%      32.770173
# 50%      32.777102
# 75%      35.192264
# max      36.345665
# Name: latitude, dtype: float64

# %%
# summary stats
df['longitude'].describe()
# Out:
# count     27.000000
# mean     132.510088
# std        4.461229
# min      127.685584
# 25%      129.863105
# 50%      129.868504
# 75%      136.705019
# max      139.822356
# Name: longitude, dtype: float64

# %%
# mean 平均値
df['latitude'].mean()
# Out:
# 32.634731682222224

# %%
# median 中央値
df['latitude'].median()
# Out:
# 32.77710225

# %%
# get center lat/lon
center_lat = df['latitude'].mean()
center_lon = df['longitude'].mean()

print(center_lat,center_lon)
# Out:
# 32.634731682222224 132.51008841851854

# %%
# loop through your data
for index, row in df.iterrows():
    print(row['name'],row['latitude'])
# Out:
# 広島平和記念資料館 34.40817299
# 広島 原爆ドーム 34.39613812
# 広島平和記念公園 34.39331227
# 広島原子爆弾 爆心地 34.39544552
# 長崎原爆資料館 32.77262813
# 長崎原爆死没者 追悼平和祈念館 32.77230337
# 長崎原子爆弾落下中心地碑 32.7739087
# 爆心地公園 32.77338548
# 平和の泉 32.77565821
# 山王神社二の鳥居（長崎原爆遺跡） 32.76804315
# カトリック浦上教会（浦上天主堂） 32.7770102
# 平和公園 32.77710225
# 平和祈念像 32.77763606
# ひめゆりの塔 26.09661602
# ひめゆり平和祈念資料館 26.09649076
# ひむかいの塔 26.09503586
# 梯梧之塔 26.09709777
# 琉風之碑 26.09670041
# 水俣市立水俣病資料館 32.20371293
# 阪神・淡路大震災記念 人と防災未来センター 34.69848324
# 東京大空襲・戦災資料センター 35.68604378
# 平和祈念展示資料館 35.69630009
# アクティブ・ミュージアム「女たちの戦争と平和資料館」 35.7138638
# しょうけい館（戦傷病者史料館） 35.70466425
# 遊就館 35.7021045
# 戦没画学生慰霊美術館 無言館 36.34566495
# 傷ついた画布のドーム オリーヴの読書館 36.34423261

# %%
# loop and output multiple column values
for index, row in df.iterrows():
    print(row['name'],row['latitude'],row['longitude'])
# Out:
# 広島平和記念資料館 34.40817299 132.4673863
# 広島 原爆ドーム 34.39613812 132.4536778
# 広島平和記念公園 34.39331227 132.4523488
# 広島原子爆弾 爆心地 34.39544552 132.4550527
# 長崎原爆資料館 32.77262813 129.8652337
# 長崎原爆死没者 追悼平和祈念館 32.77230337 129.8649869
# 長崎原子爆弾落下中心地碑 32.7739087 129.8632918
# 爆心地公園 32.77338548 129.8631416
# 平和の泉 32.77565821 129.8630685
# 山王神社二の鳥居（長崎原爆遺跡） 32.76804315 129.8672196
# カトリック浦上教会（浦上天主堂） 32.7770102 129.8685038
# 平和公園 32.77710225 129.8630507
# 平和祈念像 32.77763606 129.8642782
# ひめゆりの塔 26.09661602 127.6906692
# ひめゆり平和祈念資料館 26.09649076 127.6902615
# ひむかいの塔 26.09503586 127.6933192
# 梯梧之塔 26.09709777 127.6918065
# 琉風之碑 26.09670041 127.6855839
# 水俣市立水俣病資料館 32.20371293 130.3746995
# 阪神・淡路大震災記念 人と防災未来センター 34.69848324 135.21
# 東京大空襲・戦災資料センター 35.68604378 139.8223561
# 平和祈念展示資料館 35.69630009 139.6877886
# アクティブ・ミュージアム「女たちの戦争と平和資料館」 35.7138638 139.7159411
# しょうけい館（戦傷病者史料館） 35.70466425 139.7543932
# 遊就館 35.7021045 139.7436163
# 戦没画学生慰霊美術館 無言館 36.34566495 138.2000375
# 傷ついた画布のドーム オリーヴの読書館 36.34423261 138.2006743

# %%
# make the map
m = folium.Map(location=[center_lat,center_lon], zoom_start=5)

# df をループしてマーカーを作る
for index, row in df.iterrows():
    latlon = [row['latitude'],row['longitude']]
    folium.Marker(latlon, 
                  popup='<div style="width:250px">'+str(row['description'])+'</div>', 
                  tooltip=row['name'],
                  icon=folium.Icon(color=row['color']
                )).add_to(m)

# show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3c993fe9cb22b71c0c17952d169588c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3c993fe9cb22b71c0c17952d169588c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3c993fe9cb22b71c0c17952d169588c4 = L.map(
#                 &quot;map_3c993fe9cb22b71c0c17952d169588c4&quot;,
#                 {
#                     center: [32.634731682222224, 132.51008841851854],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc3c7c82eddeb790de5fa244bd4269c0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3c993fe9cb22b71c0c17952d169588c4);
#
#
#             var marker_542be6d475c54dfeaaf253be75764b9c = L.marker(
#                 [34.40817299, 132.4673863],
#                 {}
#             ).addTo(map_3c993fe9cb22b71c0c17952d169588c4);
#
#
#             var icon_b208a4ec93797a50bcfc5c71315f1fad = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_542be6d475c54dfeaaf253be75764b9c.setIcon(icon_b208a4ec93797a50bcfc5c71315f1fad);
#
#
#         var popup_33f26db9b5525d518dfb6e7321c9159f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8abb45df611beb53d6c118a0e01f3a51 = $(`&lt;div id=&quot;html_8abb45df611beb53d6c118a0e01f3a51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:250px&quot;&gt;nan&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_33f26db9b5525d518dfb6e7321c9159f.setContent(html_8abb45df611beb53d6c118a0e01f3a51);
#
#
#
#         marker_542be6d475c54dfeaaf253be75764b9c.bindPopup(popup_33f26db9b5525d518dfb6e7321c9159f)
#         ;
#
#
#
#
#             marker_542be6d475c54dfeaaf253be75764b9c.bindTooltip(
#                 `&lt;div&gt;
#                      広島平和記念資料館
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a71fdf54b304ce9ac7d74feffa0ae45a = L.marker(
#                 [34.39613812, 132.4536778],
#                 {}
#             ).addTo(map_3c993fe9cb22b71c0c17952d169588c4);
#
#
#             var icon_37380174e4b3f946b6521d6e36986b95 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a71fdf54b304ce9ac7d74feffa0ae45a.setIcon(icon_37380174e4b3f946b6521d6e36986b95);
#
#
#         var popup_21c0a2cc023bc484c9b7586b1f1bda3f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9920c1de7098f730250d616b85c0b092 = $(`&lt;div id=&quot;html_9920c1de7098f730250d616b85c0b092&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:250px&quot;&gt;nan&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_21c0a2cc023bc484c9b7586b1f1bda3f.setContent(html_9920c1de7098f730250d616b85c0b092);
#
#
#
#         marker_a71fdf54b304ce9ac7d74feffa0ae45a.bindPopup(popup_21c0a2cc023bc484c9b7586b1f1bda3f)
#         ;
#
#
#
#
#             marker_a71fdf54b304ce9ac7d74feffa0ae45a.bindTooltip(
#                 `&lt;div&gt;
#                      広島 原爆ドーム
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_080abd269b9af007b8be4de9b5dc17b0 = L.marker(
#                 [34.39331227, 132.4523488],
#                 {}
#             ).addTo(map_3c993fe9cb22b71c0c17952d169588c4);
#
#
#             var icon_74aa9a09159e59aec45085bef2b358c9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_080abd269b9af007b8be4de9b5dc17b0.setIcon(icon_74aa9a09159e59aec45085bef2b358c9);
#
#
#         var popup_98f94593d38d7fbe42e592ef45ceae44 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_808fc846a4e3b7d1f2b7d503e2974e88 = $(`&lt;div id=&quot;html_808fc846a4e3b7d1f2b7d503e2974e88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:250px&quot;&gt;所在】広島県広島市中区大手町1丁目10
#  【利用料金】無料
#  【駐車場】周辺の有料駐車場をご

# %%
# make the map
m = folium.Map(location=[center_lat,center_lon], 
               zoom_start=5,
               attr = '国土地理院')

# add basemaps
folium.TileLayer(name='2007年以降',tiles='https://cyberjapandata.gsi.go.jp/xyz/seamlessphoto/{z}/{x}/{y}.jpg',attr='国土地理院').add_to(m)
folium.TileLayer(name='1987年～1990年',tiles='https://cyberjapandata.gsi.go.jp/xyz/gazo4/{z}/{x}/{y}.jpg',attr='国土地理院').add_to(m)
folium.TileLayer(name='1984年～1986年',tiles='https://cyberjapandata.gsi.go.jp/xyz/gazo3/{z}/{x}/{y}.jpg',attr='国土地理院').add_to(m)
folium.TileLayer(name='1979年～1983年',tiles='https://cyberjapandata.gsi.go.jp/xyz/gazo2/{z}/{x}/{y}.jpg',attr='国土地理院').add_to(m)
folium.TileLayer(name='1974年～1978年',tiles='https://cyberjapandata.gsi.go.jp/xyz/gazo1/{z}/{x}/{y}.jpg',attr='国土地理院').add_to(m)
folium.TileLayer(name='1961年～1969年',tiles='https://cyberjapandata.gsi.go.jp/xyz/ort_old10/{z}/{x}/{y}.png',attr='国土地理院').add_to(m)

# basemapが選べるボタンをマップに足す
folium.LayerControl().add_to(m)

# add points
for index, row in df.iterrows():
    latlon = [row['latitude'],row['longitude']]
    folium.Marker(latlon, popup='<div style="width:350px">'+str(row['description'])+'</div>', tooltip=row['name'],icon=folium.Icon(color=row['color'])).add_to(m)

# show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b284e0beaed7dec088f6ef9c716faf30 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b284e0beaed7dec088f6ef9c716faf30&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b284e0beaed7dec088f6ef9c716faf30 = L.map(
#                 &quot;map_b284e0beaed7dec088f6ef9c716faf30&quot;,
#                 {
#                     center: [32.634731682222224, 132.51008841851854],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aaf0480239790154cd48501ac9b98db1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b284e0beaed7dec088f6ef9c716faf30);
#
#
#             var tile_layer_6d9ba929b6f75cd0cb8ebfee71fff5e8 = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/seamlessphoto/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b284e0beaed7dec088f6ef9c716faf30);
#
#
#             var tile_layer_5fa87f9a68fbb9e98fd5de0aeed4812e = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/gazo4/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b284e0beaed7dec088f6ef9c716faf30);
#
#
#             var tile_layer_8a0b308baa7fa369c775641564ca8211 = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/gazo3/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b284e0beaed7dec088f6ef9c716faf30);
#
#
#             var tile_layer_b10b0e3ebc7e121ffa39efe2493e0221 = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/gazo2/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b284e0beaed7dec088f6ef9c716faf30);
#
#
#             var tile_layer_6cd4f77e7039cc3c10adbda925819aaf = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/gazo1/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b284e0beaed7dec088f6ef9c716faf30);
#
#
#             var tile_layer_b818784010940993939be28825602d3e = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/ort_old10/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b284e0beaed7dec088f6ef9c716faf30);
#
#
#             var layer_control_a292e6ad4680f99072a6d13150f0ad95 = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_aaf0480239790154cd48501ac9b98db1,
#                     &quot;2007\u5e74\u4ee5\u964d&quot; : tile_layer_6d9ba929b6f75cd0cb8ebfee71fff5e8,
#                     &quot;1987\u5e74\uff5e1990\u5e74&quot; : tile_layer_5fa87f9a68fbb9e98fd5de0aeed4812e,
#                     &quot;1984\u5e74\uff5e1986\u5e74&quot; : tile_layer_8a0b308baa7fa369c775641564ca8211,
#                     &quot;1979\u5e74\uff5e1983\u5e74&quot; : tile_layer_b10b0e3ebc7e121ffa39efe2493e0221,
#                     &quot;1974\u5e74\uff5e1978\u5e74&quot; : tile_layer_6cd4f77e7039cc3c10adbda925819aaf,
#                     &quot;1961\

# %%
m.save('map.html')

# %% [markdown]
# # Darktourism Map

# %% [markdown]
# ## GISの授業の中の目標が原爆で被爆した広島と長崎を中心に戦時中から戦後にかけてのマップを作ることだったので、今回広島と長崎と今まで訪れた戦争に関連する資料館や負の遺産として提唱されると推奨されている資料館をマップにして作ってみました。Darktourismという言葉も今回のワークを取り組みながら初めて知ることができました。Darktourismとは戦跡や被害被災地など、死・暴力・虐待などの悲劇にまつわる場所を訪問する観光のこと。私はこのpython GIS mapを通してまるでDarktourismをしているような体験、Darktourismに関する資料館を知る機会になればと思い作りました。しかし、実際のところまだ工夫する必要があると思いました。画像を挿入したり、もっとGISを通して疑似体験ができるようにGISのスキルを磨いていこうと思います。
