# %%
import geopandas as gpd
import pandas as pd

# %%
hiroshima_ku = gpd.read_file('hiroshima_ku.geojson')

# %%
hiroshima_ku.plot()
# Out:
# <Axes: >

# %%
hiroshima_ku.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    699 non-null    float64
#  1   N03_001     699 non-null    object
#  2   N03_002     0 non-null      object
#  3   N03_003     118 non-null    object
#  4   N03_004     699 non-null    object
#  5   N03_007     699 non-null    object
#  6   Shape_Leng  699 non-null    float64
#  7   Shape_Area  699 non-null    float64
#  8   geometry    699 non-null    geometry
# dtypes: float64(3), geometry(1), object(5)
# memory usage: 49.3+ KB

# %%
hiroshima_pop = pd.read_csv('hiroshima.csv')

# %%
hiroshima_pop.head()
# Out:
#     KEY_CODE  HYOSYO CITYNAME   NAME  HTKSYORI  HTKSAKI  GASSAN    人口総数  \
# 0      34101       1    広島市中区    NaN         0      NaN     NaN  142699
# 1  341010430       2    広島市中区   白島北町         0      NaN     NaN    1969
# 2  341010440       2    広島市中区   白島中町         0      NaN     NaN    1210
# 3  341010450       2    広島市中区  白島九軒町         0      NaN     NaN    1408
# 4  341010460       2    広島市中区   東白島町         0      NaN     NaN    3918
#
#        男      女   世帯総数
# 0  67660  75039  81602
# 1    837   1132   1160
# 2    565    645    660
# 3    642    766    797
# 4   1858   2060   2217

# %%
hiroshima_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4976 entries, 0 to 4975
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   KEY_CODE  4976 non-null   int64
#  1   HYOSYO    4976 non-null   int64
#  2   CITYNAME  4976 non-null   object
#  3   NAME      4929 non-null   object
#  4   HTKSYORI  4976 non-null   int64
#  5   HTKSAKI   0 non-null      float64
#  6   GASSAN    0 non-null      float64
#  7   人口総数      4976 non-null   object
#  8   男         4976 non-null   object
#  9   女         4976 non-null   object
#  10  世帯総数      4976 non-null   object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 427.8+ KB

# %%
hiroshima_ku.rename(columns={'N03_007':'KEY_CODE'},inplace=True)

# %%
hiroshima_ku
# Out:
#      OBJECTID N03_001 N03_002 N03_003     N03_004 KEY_CODE  Shape_Leng  \
# 0         1.0  L§    None  Ls  Lsæ    34101    0.185225
# 1         2.0  L§    None  Ls  Lsæ    34102    0.333568
# 2         3.0  L§    None  Ls  Lsìæ    34103    0.009511
# 3         4.0  L§    None  Ls  Lsìæ    34103    0.020938
# 4         5.0  L§    None  Ls  Lsìæ    34103    0.001005
# ..        ...     ...     ...     ...         ...      ...         ...
# 694     695.0  L§    None  LcS  åèã¬    34431    0.002379
# 695     696.0  L§    None  LcS  åèã¬    34431    0.015755
# 696     697.0  L§    None  LcS  åèã¬    34431    0.135284
# 697     698.0  L§    None  ¢
# S      ¢
# ¬    34462    1.054925
# 698     699.0  L§    None  _ÎS  _Î´¬    34545    1.239023
#
#        Shape_Area                                           geometry
# ...

# %%
hiroshima_ku['KEY_CODE'] = hiroshima_ku['KEY_CODE'].astype(int)

# %%
hiroshima_ku.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    699 non-null    float64
#  1   N03_001     699 non-null    object
#  2   N03_002     0 non-null      object
#  3   N03_003     118 non-null    object
#  4   N03_004     699 non-null    object
#  5   KEY_CODE    699 non-null    int32
#  6   Shape_Leng  699 non-null    float64
#  7   Shape_Area  699 non-null    float64
#  8   geometry    699 non-null    geometry
# dtypes: float64(3), geometry(1), int32(1), object(4)
# memory usage: 46.5+ KB

# %%
hiroshima_ku_pop = hiroshima_ku.merge(hiroshima_pop,on='KEY_CODE')

# %%
hiroshima_pop
# Out:
#        KEY_CODE  HYOSYO CITYNAME   NAME  HTKSYORI  HTKSAKI  GASSAN    人口総数  \
# 0         34101       1    広島市中区    NaN         0      NaN     NaN  142699
# 1     341010430       2    広島市中区   白島北町         0      NaN     NaN    1969
# 2     341010440       2    広島市中区   白島中町         0      NaN     NaN    1210
# 3     341010450       2    広島市中区  白島九軒町         0      NaN     NaN    1408
# 4     341010460       2    広島市中区   東白島町         0      NaN     NaN    3918
# ...         ...     ...      ...    ...       ...      ...     ...     ...
# 4971  345450330       2    神石高原町    上豊松         0      NaN     NaN     370
# 4972  345450340       2    神石高原町    下豊松         0      NaN     NaN     345
# 4973  345450350       2    神石高原町     笹尾         0      NaN     NaN     117
# 4974  345450360       2    神石高原町     中平         0      NaN     NaN      44
# 4975  345450370       2    神石高原町     有木         0      NaN     NaN     197
#
#           男      女   世帯総数
# 0     67660  75039  81602
# ...

# %%
hiroshima_pop.info
# Out:
# <bound method DataFrame.info of        KEY_CODE  HYOSYO CITYNAME   NAME  HTKSYORI  HTKSAKI  GASSAN    人口総数  \
# 0         34101       1    広島市中区    NaN         0      NaN     NaN  142699
# 1     341010430       2    広島市中区   白島北町         0      NaN     NaN    1969
# 2     341010440       2    広島市中区   白島中町         0      NaN     NaN    1210
# 3     341010450       2    広島市中区  白島九軒町         0      NaN     NaN    1408
# 4     341010460       2    広島市中区   東白島町         0      NaN     NaN    3918
# ...         ...     ...      ...    ...       ...      ...     ...     ...
# 4971  345450330       2    神石高原町    上豊松         0      NaN     NaN     370
# 4972  345450340       2    神石高原町    下豊松         0      NaN     NaN     345
# 4973  345450350       2    神石高原町     笹尾         0      NaN     NaN     117
# 4974  345450360       2    神石高原町     中平         0      NaN     NaN      44
# 4975  345450370       2    神石高原町     有木         0      NaN     NaN     197
#
#           男      女   世帯総数
# ...

# %%
hiroshima_ku_pop['人口総数'] = hiroshima_ku_pop['人口総数'].astype(int)

# %%
hiroshima_ku_pop.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    699 non-null    float64
#  1   N03_001     699 non-null    object
#  2   N03_002     0 non-null      object
#  3   N03_003     118 non-null    object
#  4   N03_004     699 non-null    object
#  5   KEY_CODE    699 non-null    int32
#  6   Shape_Leng  699 non-null    float64
#  7   Shape_Area  699 non-null    float64
#  8   geometry    699 non-null    geometry
#  9   HYOSYO      699 non-null    int64
#  10  CITYNAME    699 non-null    object
#  11  NAME        0 non-null      object
#  12  HTKSYORI    699 non-null    int64
#  13  HTKSAKI     0 non-null      float64
#  14  GASSAN      0 non-null      float64
#  15  人口総数        699 non-null    int32
#  16  男           699 non-null    object
#  17  女           699 non-null    object
# ...

# %%
hiroshima_ku_pop.plot(column='人口総数',legend=True)
# Out:
# <Axes: >

# %%
hiroshima_ku_pop.plot(figsize=(10,10),
                  column='人口総数',
                  legend=True)
# Out:
# <Axes: >

# %%
hiroshima_ku_pop.plot(figsize=(10,10),
                  column='人口総数',
                  legend=True,
                  cmap='RdYlGn_r')
# Out:
# <Axes: >

# %%
import geopandas as gpd
import contextily as ctx
import plotly.express as px
import matplotlib.pyplot as plt

# set font
import matplotlib as mpl

# for PC
mpl.rc('font',family='MS Gothic')

# %%
gdf = gpd.read_file('B002005212020DDSWC34202.zip')

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 8508 entries, 0 to 8507
# Data columns (total 38 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   KEY_CODE   8508 non-null   object
#  1   PREF       8508 non-null   object
#  2   CITY       8508 non-null   object
#  3   K_AREA     8508 non-null   object
#  4   S_AREA     8508 non-null   object
#  5   PREF_NAME  8508 non-null   object
#  6   CITY_NAME  8508 non-null   object
#  7   S_NAME     8505 non-null   object
#  8   KIGO_E     51 non-null     object
#  9   HCODE      8508 non-null   int64
#  10  AREA       8508 non-null   float64
#  11  PERIMETER  8508 non-null   float64
#  12  KIHON1     8508 non-null   object
#  13  DUMMY1     8508 non-null   object
#  14  KIHON2     8508 non-null   object
#  15  KIHON3     8508 non-null   object
#  16  C1         8508 non-null   int64
#  17  C2         8508 non-null   int64
#  18  DUMMY2     8508 non-null   object
# ...

# %%
gdf.head()
# Out:
#        KEY_CODE PREF CITY     K_AREA   S_AREA PREF_NAME CITY_NAME  S_NAME  \
# 0  342020001101   34  202  014004050  0001101       広島県        呉市  西中央四丁目
# 1  342020001102   34  202  014004090  0001102       広島県        呉市  西中央四丁目
# 2  342020001103   34  202  014004100  0001103       広島県        呉市  西中央四丁目
# 3    3420200021   34  202  014004090    00021       広島県        呉市  西中央四丁目
# 4    3420200031   34  202  014004080    00031       広島県        呉市  西中央四丁目
#
#   KIGO_E  HCODE  ...      KEYCODE1  JINKO SETAI KEN_OLD CITY_OLD      X_CODE  \
# 0   None   8101  ...  2020001-1-01     48    29      34      202  132.561651
# 1   None   8101  ...  2020001-1-02     27    18      34      202  132.561377
# 2   None   8101  ...  2020001-1-03      0     0      34      202  132.559826
# 3   None   8101  ...  2020002-1-00     80    45      34      202  132.561190
# 4   None   8101  ...  2020003-1-00     56    38      34      202  132.560943
#
#       Y_CODE      KCODE1  CCODE1  \
# ...

# %%
gdf = gdf.dissolve(by='S_NAME',aggfunc='sum').reset_index()

# %%
fig,ax = plt.subplots()
gdf.plot(ax=ax);

# %%
#poplation_map
fig,ax = plt.subplots()
gdf.plot(ax=ax,
         column='JINKO',
         legend=True)
# Out:
# <Axes: >

# %%
fig,ax = plt.subplots(figsize=(10,10))
gdf.plot(ax=ax,
         column='JINKO',
         legend=True,
         cmap='YlGnBu',
         edgecolor='black',
         linewidth=0.2);
         legend_kwd
ax. axis('off');
